# %% [markdown]
# <a href="https://colab.research.google.com/github/ingridcos/exercicios-praticos/blob/main/TESTE_PYTHON_B%C3%81SICO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
texto = "olá, mundo!"
print(texto)
# Out:
# olá, mundo!

# %%
numero1 = 1
numero2 = 2
print(numero1)
print(numero2)
# Out:
# 1
# 2

# %%
numero1 = 10
numero2 = 3
print(numero1 % numero2)
print(numero1 + numero2)
# Out:
# 1
# 13

# %%
print(10 *3)
# Out:
# 30

# %%
numero1 = 10
numero2 = 20
soma = numero1 + numero2
print(soma)
# Out:
# 30

# %%
a = 1
b = 2.5
soma = a + b
print(type(a))
print(type(b))
print(type(soma))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'float'>

# %%
texto1 = "Olá, mundo! "
texto2 = "Meu nome é Ingrid"
texto = texto1 + texto2
print(texto)
# Out:
# Olá, mundo! Meu nome é Ingrid

# %%
eh_maior_de_idade = True
tem_carteira_de_motorista = False
pode_dirigir = eh_maior_de_idade and tem_carteira_de_motorista
print(pode_dirigir)
# Out:
# False
